# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# DSFP5.0 WEEK2

# %%
#getting to know all existing built-in function
dir(__builtins__)
# Out:
# ['ArithmeticError',
#  'AssertionError',
#  'AttributeError',
#  'BaseException',
#  'BaseExceptionGroup',
#  'BlockingIOError',
#  'BrokenPipeError',
#  'BufferError',
#  'BytesWarning',
#  'ChildProcessError',
#  'ConnectionAbortedError',
#  'ConnectionError',
#  'ConnectionRefusedError',
#  'ConnectionResetError',
#  'DeprecationWarning',
#  'EOFError',
#  'Ellipsis',
#  'EncodingWarning',
#  'EnvironmentError',
#  'Exception',
#  'ExceptionGroup',
#  'False',
#  'FileExistsError',
#  'FileNotFoundError',
#  'FloatingPointError',
#  'FutureWarning',
#  'GeneratorExit',
#  'IOError',
#  'ImportError',
#  'ImportWarning',
#  'IndentationError',
#  'IndexError',
#  'InterruptedError',
#  'IsADirectoryError',
#  'KeyError',
#  'KeyboardInterrupt',
#  'LookupError',
#  'MemoryError',
#  'ModuleNotFoundError',
#  'NameError',
#  'None',
#  'NotADirectoryError',
#  'NotImplemented',
#  'NotImplementedError',
#  'OSError',
#  'OverflowError',
#  'PendingDeprecationWarning',
# ...

# %%
print("Hello ALL!")
print("Hello ALL!")
print("Hello ALL!")
print("Hello ALL!")
# Out:
# Hello ALL!
# Hello ALL!
# Hello ALL!
# Hello ALL!

# %%
#creating your own fxns
def greeting (name):
    return "Hello ALL!"

# %%
print(greeting)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_47/3755650373.py in <cell line: 0>()
# ----> 1 print(greeting(name))
#
# NameError: name 'name' is not defined

# %%
r = float(input("Enter the radius: "))
area = 3.14 * r * r
print("Area of the circle:", area)

# %%
# Get input from the user
a = float(input("Enter the first number: "))
b = float(input("Enter the second number: "))
op = input("Enter operation (* or /): ")

# Perform calculation
if op == "*":
    result = a * b
elif op == "/":
    if b == 0:
        result = "Error: Division by zero"
    else:
        result = a / b
else:
    result = "Invalid operation"

print("Result:", result)

# %%
import math

def circle_area(radius):
    """Calculate and return the area of a circle given its radius."""
    return math.pi * radius ** 2

# Example usage:
r = float(input("Enter the radius of the circle: "))
area = circle_area(r)
print("The area of the circle is:", area)

# %% [markdown]
# day2****

# %%
def calculate_bmi(patient_name, weight_kg, height_m):
    bmi = weight_kg / (height_m**2)
    if bmi < 18.5:
        category = "Undereight"
    elif bmi <= 25:
        category = "Normal weight"
    elif bmi <= 30:
        category = "Overweight" 
    else:
        category = "obese"
   #Step 4: Prepare result 
    result = {
        "patient_name": patient_name,
        "weight_kg": weight_kg,
        "height_m": height_m,
        "bmi": round(bmi, 2),
        "category": category
     }

    return result

# %%
print(calculate_bmi("Mary", 45, 1.5))
# Out:
# {'patient_name': 'Mary', 'weight_kg': 45, 'height_m': 1.5, 'bmi': 20.0, 'category': 'Normal weight'}

# %%
def tax(income, tax_rate ):
     tax_rate = income*rate
    if gross_income < 80000:
        rate = "0%"
    elif gross_income <= 2000000:
        rate = "15%"
    elif gross_income <= 5000000:
        rate = "30%" 
    else:
        rate = "50%"
# Out:
#   File "<tokenize>", line 3
#     if gross_income < 80000:
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
#Exercise1
def tax(income):
    if income < 80000:
        rate = 0.0
    elif income <= 2000000:
        rate = 0.15
    elif income <= 5000000:
        rate = 0.30
    else:
        rate = 0.50

    tax_amount = income * rate
    return tax_amount

# %%
print( tax(250000))
# Out:
# 37500.0

# %%
#correction to exercise 1
def tax_cal(name, yr_income):
    tax = yr_income * 20/100
    if yr_income < 800000:
        return 'income not taxable'
    else:
        return f'the tax of {name} is {tax}'

# %%
tax_cal('Jubal', 900000)
# Out:
# 'the tax of Jubal is 180000.0'

# %%
#exercise2: create function that returns the square of a given number
def square(number):
    return number**2

# %%
square(3)
# Out:
# 9

# %%
#exercise3: create function that returns the max of two number
def max(number):
    number= a>b
    return b

# %%
max([2,3])
# Out:
# 4

# %%
#exercise4: create function that take a list of numbers and returns their average
list=[2,8,4,3,7]
def average(numbers):
    return sum(numbers) / len(numbers)

print(average(list))
# Out:
# 4.8

# %%
#exercise5:write a function that coverts hours and minutes
def in_minutes(hours):
    input(int(hours))
    hours = hours//60
    minutes = hours%60
    return hours, minutes

print(in_minutes(79))
# Out:
# 79 89
# (1, 1)

# %%
#exercise6:create a function that takes any number of arguement and returns their sum
def total_sum(*args): #args means agruement thats an int
    return sum(args)

# %%
print(total_sum(3,8,9,4))
# Out:
# 24

# %%
#exercise7:create function that takes any number of arguments and returns their cumulative product 
def sum_nums(*args):
    total = 1
    for i in args:
        total = total * i
    return total

# %%
sum_nums(1,2,3,4)
# Out:
# 24
